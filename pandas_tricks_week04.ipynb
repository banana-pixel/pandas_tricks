# %% [markdown]
# Materi 13 : Konversi nilai numerik ke dalam sejumlah kategori

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 10
n_cols = 1
cols = ('usia',)

df = pd.DataFrame(np.random.randint(1, 99, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    usia
# 0    22
# 1     5
# 2    45
# 3    70
# 4    35
# 5    83
# 6    74
# 7    95
# 8    50
# 9     5

# %% [markdown]
# Pengelompokkan nilai numerik ke dalam beberapa kategori menggunakan cut()

# %%
df['kelompok_usia'] = pd.cut(df['usia'], 
                             bins=[0, 18, 65, 99], 
                             labels=['anak', 'dewasa', 'manula'])
df
# Out:
#    usia kelompok_usia
# 0    22        dewasa
# 1     5          anak
# 2    45        dewasa
# 3    70        manula
# 4    35        dewasa
# 5    83        manula
# 6    74        manula
# 7    95        manula
# 8    50        dewasa
# 9     5          anak

# %% [markdown]
# Materi 14 : Menggabungkan (Merge) dua Data Frame

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#     A   B   C   D   E
# 0  16  11   2  11  19
# 1   1  12   5   4  11
# 2  13   9   9   6  16
# 3   5   5   2  16  17
# 4  12  19  10  14  12

# %%
df1 = df.copy(deep=True)
df1 = df1.drop([1, 4])
df1
# Out:
#     A   B  C   D   E
# 0  16  11  2  11  19
# 2  13   9  9   6  16
# 3   5   5  2  16  17

# %%
df2 = df.copy(deep=True)
df2 = df2.drop([0, 3])
df2
# Out:
#     A   B   C   D   E
# 1   1  12   5   4  11
# 2  13   9   9   6  16
# 4  12  19  10  14  12

# %% [markdown]
# Menggabungkan dua Data Frame

# %%
df_inner = pd.merge(df1, df2, how='inner')
df_inner
# Out:
#     A  B  C  D   E
# 0  13  9  9  6  16

# %%
df_outer = pd.merge(df1, df2, how='outer')
df_outer
# Out:
#     A   B   C   D   E
# 0   1  12   5   4  11
# 1   5   5   2  16  17
# 2  12  19  10  14  12
# 3  13   9   9   6  16
# 4  16  11   2  11  19

# %% [markdown]
# Materi 15 : Memecah nilai string dari suatu kolom ke dalam beberapa kolom baru

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# Persiapan Data Frame

# %%
data = {'nama':['Didi Kempot', 'Glenn Fredly', 'Mbah Surip'], 
        'tempat_kelahiran':['Surakarta, Jawa Tengah', 'Jakarta, DKI Jakarta', 'Mojokerto, Jawa Timur']}
df = pd.DataFrame(data)
df
# Out:
#            nama        tempat_kelahiran
# 0   Didi Kempot  Surakarta, Jawa Tengah
# 1  Glenn Fredly    Jakarta, DKI Jakarta
# 2    Mbah Surip   Mojokerto, Jawa Timur

# %% [markdown]
# Memecah nama depan dan nama belakang

# %%
df[['nama_depan', 'nama_belakang']] = df['nama'].str.split(' ', expand=True)
df
# Out:
#            nama        tempat_kelahiran nama_depan nama_belakang
# 0   Didi Kempot  Surakarta, Jawa Tengah       Didi        Kempot
# 1  Glenn Fredly    Jakarta, DKI Jakarta      Glenn        Fredly
# 2    Mbah Surip   Mojokerto, Jawa Timur       Mbah         Surip

# %% [markdown]
# Memecah nama kota dan propinsi

# %%
df[['kota', 'propinsi']] = df['tempat_kelahiran'].str.split(',', expand=True)
df
# Out:
#            nama        tempat_kelahiran nama_depan nama_belakang       kota  \
# 0   Didi Kempot  Surakarta, Jawa Tengah       Didi        Kempot  Surakarta
# 1  Glenn Fredly    Jakarta, DKI Jakarta      Glenn        Fredly    Jakarta
# 2    Mbah Surip   Mojokerto, Jawa Timur       Mbah         Surip  Mojokerto
#
#        propinsi
# 0   Jawa Tengah
# 1   DKI Jakarta
# 2    Jawa Timur

# %% [markdown]
# Materi 16 : Menata ulang Data Frame dengan mutiple indexes menggunakan unstack()

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# Persiapan Data Frame

# %%
df = pd.read_csv('data/titanicfull.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# Data Frame dengan multiple indexes dari hasil groupping

# %%
df.groupby(['sex', 'pclass'])['survived'].mean().to_frame()
# Out:
#                survived
# sex    pclass
# female 1       0.965278
#        2       0.886792
#        3       0.490741
# male   1       0.340782
#        2       0.146199
#        3       0.152130

# %% [markdown]
# Menata ulang Data Frame dengan mutiple indexes

# %%
df.groupby(['sex', 'pclass'])['survived'].mean().unstack()
# Out:
# pclass         1         2         3
# sex
# female  0.965278  0.886792  0.490741
# male    0.340782  0.146199  0.152130
