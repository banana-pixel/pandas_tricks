# %% [markdown]
# Materi 53: Membuat kategori baru berdasarkan threshold (ambang batas)

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# Persiapan Data Frame

# %%
d = {'hobi':['jogging', 'mancing', 'renang',
             'mancing', 'mancing', 'baca', 
             'baca', 'mancing', 'fotograsi', 
             'mancing', 'camping']}

df = pd.DataFrame(d)
df
# Out:
#          hobi
# 0     jogging
# 1     mancing
# 2      renang
# 3     mancing
# 4     mancing
# 5        baca
# 6        baca
# 7     mancing
# 8   fotograsi
# 9     mancing
# 10    camping

# %% [markdown]
# Membuat kategori baru berdasarkan threshold (ambang batas)

# %%
df['hobi'].value_counts()
# Out:
# hobi
# mancing      5
# baca         2
# jogging      1
# renang       1
# fotograsi    1
# camping      1
# Name: count, dtype: int64

# %%
persentase = df['hobi'].value_counts(normalize=True)
persentase
# Out:
# hobi
# mancing      0.454545
# baca         0.181818
# jogging      0.090909
# renang       0.090909
# fotograsi    0.090909
# camping      0.090909
# Name: proportion, dtype: float64

# %%
threshold = 0.1
hobi_lain = persentase[persentase < threshold].index
hobi_lain
# Out:
# Index(['jogging', 'renang', 'fotograsi', 'camping'], dtype='object', name='hobi')

# %%
df['hobi'] = df['hobi'].replace(hobi_lain, 'lainnya')
df['hobi']
# Out:
# 0     lainnya
# 1     mancing
# 2     lainnya
# 3     mancing
# 4     mancing
# 5        baca
# 6        baca
# 7     mancing
# 8     lainnya
# 9     mancing
# 10    lainnya
# Name: hobi, dtype: object

# %%
df['hobi'].value_counts(normalize=True)
# Out:
# hobi
# mancing    0.454545
# lainnya    0.363636
# baca       0.181818
# Name: proportion, dtype: float64

# %% [markdown]
# Materi 54 : Menyimpan Data Frame sebagai file CSV

# %% [markdown]
# Persiapan Data Frame

# %%
data = {'nama': ['bayu', 'indra', 'devi', 'agni'],
        'jenis kelamin': ['L', 'L', 'P', 'L'],
        'usia': [23, 21, 20, 25]}

df = pd.DataFrame(data)
df
# Out:
#     nama jenis kelamin  usia
# 0   bayu             L    23
# 1  indra             L    21
# 2   devi             P    20
# 3   agni             L    25

# %% [markdown]
# Menyimpan Data Frame sebagai file CSV

# %%
df.to_csv('data_peserta.csv')

# %%
df = pd.read_csv('data_peserta.csv', index_col=0)
df
# Out:
#     nama jenis kelamin  usia
# 0   bayu             L    23
# 1  indra             L    21
# 2   devi             P    20
# 3   agni             L    25

# %%
df.to_csv('data_peserta.csv', index=False)
df = pd.read_csv('data_peserta.csv')
df
# Out:
#     nama jenis kelamin  usia
# 0   bayu             L    23
# 1  indra             L    21
# 2   devi             P    20
# 3   agni             L    25

# %% [markdown]
# Materi 55 : Menghitung Jumlah Baris Menurut Kriteria Tertentu

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 10
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  9  8  4  5  3
# 1  3  8  3  1  8
# 2  7  8  4  2  8
# 3  3  3  8  1  3
# 4  3  9  5  5  4
# 5  1  7  8  2  2
# 6  3  4  3  7  2
# 7  8  9  9  6  3
# 8  5  7  4  6  5
# 9  1  1  3  6  7

# %% [markdown]
# Menghitung jumlah baris menurut kriteria tertentu

# %%
(df['A'] < 5).sum()
# Out:
# np.int64(6)

# %%
(df['A'] < 5).mean()
# Out:
# np.float64(0.2)

# %% [markdown]
# Materi 56: Mengeluarkan kolom dari Data Frame

# %% [markdown]
# Persiapan Data Frame

# %%
data = {'nama': ['bayu', 'indra', 'devi', 'agni'],
        'jenis kelamin': ['L', 'L', 'P', 'L'],
        'usia': [23, 21, 22, 25]}

df = pd.DataFrame(data)
df
# Out:
#     nama jenis kelamin  usia
# 0   bayu             L    23
# 1  indra             L    21
# 2   devi             P    22
# 3   agni             L    25

# %% [markdown]
# Mengeluarkan kolom dari Data Frame

# %%
usia = df.pop('usia').to_frame()

# %%
df
# Out:
#     nama jenis kelamin
# 0   bayu             L
# 1  indra             L
# 2   devi             P
# 3   agni             L

# %%
usia
# Out:
#    usia
# 0    23
# 1    21
# 2    22
# 3    25
