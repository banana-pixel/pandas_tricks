# %% [markdown]
# #05: Membalik urutan baris dan kolom pada Data Frame

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  6  6  7  3  3
# 1  9  9  8  3  1
# 2  5  9  1  9  7
# 3  9  4  5  7  4
# 4  2  2  2  7  2

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  3  3  7  6  6
# 1  1  3  8  9  9
# 2  7  9  1  9  5
# 3  4  7  5  4  9
# 4  2  7  2  2  2

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  2  2  2  7  2
# 3  9  4  5  7  4
# 2  5  9  1  9  7
# 1  9  9  8  3  1
# 0  6  6  7  3  3

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  2  2  2  7  2
# 1  9  4  5  7  4
# 2  5  9  1  9  7
# 3  9  9  8  3  1
# 4  6  6  7  3  3

# %% [markdown]
# #06: Mengganti nama (label) kolom pada Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  6  5  5  4  8
# 1  7  1  9  7  6
# 2  1  6  1  3  5
# 3  3  8  4  7  1
# 4  2  4  3  4  2

# %%
df.rename(columns={'C':'Hobi'})
# Out:
#    A  B  Hobi  D  E
# 0  6  5     5  4  8
# 1  7  1     9  7  6
# 2  1  6     1  3  5
# 3  3  8     4  7  1
# 4  2  4     3  4  2

# %%
df.rename(columns={'A':'Nama', 'B':'Alamat', 'D':'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     6       5  5     4  8
# 1     7       1  9     7  6
# 2     1       6  1     3  5
# 3     3       8  4     7  1
# 4     2       4  3     4  2

# %% [markdown]
# #07: Menghapus (drop) missing values (NaN)

# %%
n_rows = 30
n_cols = 4
cols = ['A', 'B', 'C', 'D']

df = pd.DataFrame(np.random.randn(n_rows, n_cols), columns=cols)

nan_mask = np.random.rand(n_rows, n_cols) < 0.2
df[nan_mask] = np.nan

df = df.reset_index()
df.head()
# Out:
#    index         A         B         C         D
# 0      0       NaN -0.372576  0.806665  1.098202
# 1      1 -0.831087  0.632925  0.491354       NaN
# 2      2 -0.798423       NaN       NaN  0.572901
# 3      3 -1.800771 -1.142879 -1.026070  0.204921
# 4      4  0.504241       NaN -1.692663  1.366820

# %%
df = df.rename(columns={'index':'Z'})
df.head()
# Out:
#    Z         A         B         C         D
# 0  0       NaN -0.372576  0.806665  1.098202
# 1  1 -0.831087  0.632925  0.491354       NaN
# 2  2 -0.798423       NaN       NaN  0.572901
# 3  3 -1.800771 -1.142879 -1.026070  0.204921
# 4  4  0.504241       NaN -1.692663  1.366820

# %%
df_backup = df.copy(deep=True)

# %%
df = df.dropna(axis='columns') 
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#      Z         A         B         C         D
# 3    3 -1.800771 -1.142879 -1.026070  0.204921
# 5    5  0.136560 -1.123548  2.123716 -3.081011
# 8    8  1.214028 -1.602561  1.901588 -0.090897
# 11  11  0.709405  0.567582 -1.810851  0.097695
# 14  14  1.261772 -0.341679 -0.916146  0.841777

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.000000
# A    0.200000
# B    0.233333
# C    0.133333
# D    0.200000
# dtype: float64

# %%
treshold = len(df) * 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# #08: Memeriksa kesamaan antar dua buah kolom (Series) pada Data Frame

# %%
data = {'A':[15, 15, 18, np.nan, 12], 
        'B':[15, 15, 18, np.nan, 12]}

df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %%
df['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['A'] == df['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df['A'].equals(df['B'])
# Out:
# True

# %%
df1 = df.copy(deep=True)

df.equals(df1)
# Out:
# True

# %%
df == df1
# Out:
#        A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
